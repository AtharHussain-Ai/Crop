# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
# %matplotlib inline
print(os.getcwd())  
import os
from subprocess import check_output, CalledProcessError

input_dir = "./input"

if os.path.exists(input_dir):
    try:
        print(check_output(["ls", input_dir]).decode("utf8"))
    except CalledProcessError as e:
        print(f"An error occurred: {e}")
else:
    print(f"The directory '{input_dir}' does not exist.")
# Out:
# /Users/md.atharhussain/Desktop/crop
# datafile (1).csv
# datafile (2).csv
# datafile (3).csv
# datafile.csv
# produce.csv

# %%
crops_prod_data = pd.read_csv("./input/datafile.csv",index_col='Crop')
print(crops_prod_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, Rice to nan
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2004-05  12 non-null     float64
#  1   2005-06  12 non-null     float64
#  2   2006-07  12 non-null     float64
#  3   2007-08  12 non-null     float64
#  4   2008-09  12 non-null     float64
#  5   2009-10  12 non-null     float64
#  6   2010-11  12 non-null     float64
#  7   2011-12  12 non-null     float64
# dtypes: float64(8)
# memory usage: 936.0+ bytes
# None

# %%
print(crops_prod_data)
# Out:
#                      2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# Crop
# Rice                   100.0    101.0     99.0    105.0    112.0    121.0
# Wheat                  100.0    101.0    112.0    115.0    117.0    127.0
# Coarse Cereals         100.0    107.0    110.0    115.0    113.0    123.0
# Pulses                 100.0    108.0    134.0    124.0    124.0    146.0
# Vegetables             100.0    109.0    103.0    118.0    113.0    124.0
# Fruits                 100.0     99.0     99.0     98.0    102.0    104.0
# Milk                   100.0     97.0     98.0     98.0     98.0    112.0
# Eggs, Fish and Meat    100.0    102.0    101.0    100.0     99.0    116.0
# Oilseeds               100.0     86.0     85.0     97.0    104.0    103.0
# Sugarcane              100.0     96.0     91.0     87.0     80.0     81.0
# Fibers                 100.0     92.0     91.0     96.0    109.0    107.0
# All Agriculture        100.0     99.0    101.0    104.0    106.0    115.0
# NaN                      NaN      NaN      NaN      NaN      NaN      NaN
#
#                      2010-11  2011-12
# Crop
# Rice                   117.0    110.0
# Wheat                  120.0    108.0
# Coarse Cereals         122.0    136.0
# Pulses                 137.0    129.0
# Vegetables             128.0    115.0
# Fruits                 114.0    119.0
# Milk                   123.0    124.0
# Eggs, Fish and Meat    133.0    137.0
# Oilseeds                99.0    102.0
# Sugarcane              109.0    107.0
# Fibers                 138.0    140.0
# All Agriculture        123.0    122.0
# NaN                      NaN      NaN

# %%
# drop all rows with Nan values
crops_prod_data = crops_prod_data.dropna()
print(crops_prod_data)
# Out:
#                      2004-05  2005-06  2006-07  2007-08  2008-09  2009-10  \
# Crop
# Rice                   100.0    101.0     99.0    105.0    112.0    121.0
# Wheat                  100.0    101.0    112.0    115.0    117.0    127.0
# Coarse Cereals         100.0    107.0    110.0    115.0    113.0    123.0
# Pulses                 100.0    108.0    134.0    124.0    124.0    146.0
# Vegetables             100.0    109.0    103.0    118.0    113.0    124.0
# Fruits                 100.0     99.0     99.0     98.0    102.0    104.0
# Milk                   100.0     97.0     98.0     98.0     98.0    112.0
# Eggs, Fish and Meat    100.0    102.0    101.0    100.0     99.0    116.0
# Oilseeds               100.0     86.0     85.0     97.0    104.0    103.0
# Sugarcane              100.0     96.0     91.0     87.0     80.0     81.0
# Fibers                 100.0     92.0     91.0     96.0    109.0    107.0
# All Agriculture        100.0     99.0    101.0    104.0    106.0    115.0
#
#                      2010-11  2011-12
# Crop
# Rice                   117.0    110.0
# Wheat                  120.0    108.0
# Coarse Cereals         122.0    136.0
# Pulses                 137.0    129.0
# Vegetables             128.0    115.0
# Fruits                 114.0    119.0
# Milk                   123.0    124.0
# Eggs, Fish and Meat    133.0    137.0
# Oilseeds                99.0    102.0
# Sugarcane              109.0    107.0
# Fibers                 138.0    140.0
# All Agriculture        123.0    122.0

# %%
# plots for individual crops
crops_prod_data.loc['Rice',:].plot()
crops_prod_data.loc['Milk',:].plot()
crops_prod_data.loc['All Agriculture',:].plot()
plt.legend(loc='upper left')

# %%
# print index of dataframe
print(crops_prod_data.index)
# Out:
# Index(['Rice', 'Wheat', 'Coarse Cereals', 'Pulses', 'Vegetables ', 'Fruits',
#        'Milk', 'Eggs, Fish and Meat', 'Oilseeds', 'Sugarcane ', 'Fibers',
#        'All Agriculture'],
#       dtype='object', name='Crop')

# %%
print(crops_prod_data.T)
# Out:
# Crop      Rice  Wheat  Coarse Cereals  Pulses  Vegetables   Fruits   Milk  \
# 2004-05  100.0  100.0           100.0   100.0        100.0   100.0  100.0
# 2005-06  101.0  101.0           107.0   108.0        109.0    99.0   97.0
# 2006-07   99.0  112.0           110.0   134.0        103.0    99.0   98.0
# 2007-08  105.0  115.0           115.0   124.0        118.0    98.0   98.0
# 2008-09  112.0  117.0           113.0   124.0        113.0   102.0   98.0
# 2009-10  121.0  127.0           123.0   146.0        124.0   104.0  112.0
# 2010-11  117.0  120.0           122.0   137.0        128.0   114.0  123.0
# 2011-12  110.0  108.0           136.0   129.0        115.0   119.0  124.0
#
# Crop     Eggs, Fish and Meat  Oilseeds  Sugarcane   Fibers  All Agriculture
# 2004-05                100.0     100.0       100.0   100.0            100.0
# 2005-06                102.0      86.0        96.0    92.0             99.0
# 2006-07                101.0      85.0        91.0    91.0            101.0
# 2007-08                100.0      97.0        87.0    96.0            104.0
# 2008-09                 99.0     104.0        80.0   109.0            106.0
# 2009-10                116.0     103.0        81.0   107.0            115.0
# 2010-11                133.0      99.0       109.0   138.0            123.0
# 2011-12                137.0     102.0       107.0   140.0            122.0

# %%
# Get current size of figure
fig_size = plt.rcParams["figure.figsize"]

# %%
# Prints: current size
print("Current size:", fig_size)
# Set figure width to 12 and height to 9
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size
# plot the transposed dataset
crops_prod_data.T.plot(subplots=True,layout=(3,4))
plt.xticks(rotation=45)
plt.tight_layout()
# Out:
# Current size: [18.0, 18.0]

# %%
# now move to another dataset
cultivation_data = pd.read_csv("./input/datafile (1).csv")
print(cultivation_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Crop                                   49 non-null     object
#  1   State                                  49 non-null     object
#  2   Cost of Cultivation (`/Hectare) A2+FL  49 non-null     float64
#  3   Cost of Cultivation (`/Hectare) C2     49 non-null     float64
#  4   Cost of Production (`/Quintal) C2      49 non-null     float64
#  5   Yield (Quintal/ Hectare)               49 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 2.4+ KB
# None

# %%
print(cultivation_data.head())
print(cultivation_data.columns)
# Out:
#     Crop           State  Cost of Cultivation (`/Hectare) A2+FL  \
# 0  ARHAR   Uttar Pradesh                                9794.05
# 1  ARHAR       Karnataka                               10593.15
# 2  ARHAR         Gujarat                               13468.82
# 3  ARHAR  Andhra Pradesh                               17051.66
# 4  ARHAR     Maharashtra                               17130.55
#
#    Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2  \
# 0                            23076.74                            1941.55
# 1                            16528.68                            2172.46
# 2                            19551.90                            1898.30
# 3                            24171.65                            3670.54
# 4                            25270.26                            2775.80
#
#    Yield (Quintal/ Hectare)
# 0                       9.83
# 1                       7.47
# 2                       9.59
# 3                       6.42
# 4                       8.72
# Index(['Crop', 'State', 'Cost of Cultivation (`/Hectare) A2+FL',
#        'Cost of Cultivation (`/Hectare) C2',
#        'Cost of Production (`/Quintal) C2', 'Yield (Quintal/ Hectare) '],
#       dtype='object')

# %%
# Add additional columns in dataframe
cultivation_data['Per Hectare Cost Price'] = cultivation_data['Cost of Production (`/Quintal) C2'] * cultivation_data['Yield (Quintal/ Hectare) ']
cultivation_data['Cost of cultivation per hectare'] = cultivation_data['Cost of Cultivation (`/Hectare) A2+FL'] + cultivation_data['Cost of Cultivation (`/Hectare) C2']
cultivation_data['Yield in Kg per hectare'] = cultivation_data['Yield (Quintal/ Hectare) '] * 100
print(cultivation_data.head())
# Out:
#     Crop           State  Cost of Cultivation (`/Hectare) A2+FL  \
# 0  ARHAR   Uttar Pradesh                                9794.05
# 1  ARHAR       Karnataka                               10593.15
# 2  ARHAR         Gujarat                               13468.82
# 3  ARHAR  Andhra Pradesh                               17051.66
# 4  ARHAR     Maharashtra                               17130.55
#
#    Cost of Cultivation (`/Hectare) C2  Cost of Production (`/Quintal) C2  \
# 0                            23076.74                            1941.55
# 1                            16528.68                            2172.46
# 2                            19551.90                            1898.30
# 3                            24171.65                            3670.54
# 4                            25270.26                            2775.80
#
#    Yield (Quintal/ Hectare)   Per Hectare Cost Price  \
# 0                       9.83              19085.4365
# 1                       7.47              16228.2762
# 2                       9.59              18204.6970
# 3                       6.42              23564.8668
# 4                       8.72              24204.9760
#
#    Cost of cultivation per hectare  Yield in Kg per hectare
# 0                         32870.79                    983.0
# 1                         27121.83                    747.0
# 2                         33020.72                    959.0
# 3                         41223.31                    642.0
# 4                         42400.81                    872.0

# %%
# checking transposed dataframe
print(cultivation_data.T.head())
# Out:
#                                                   0          1         2   \
# Crop                                           ARHAR      ARHAR     ARHAR
# State                                  Uttar Pradesh  Karnataka   Gujarat
# Cost of Cultivation (`/Hectare) A2+FL        9794.05   10593.15  13468.82
# Cost of Cultivation (`/Hectare) C2          23076.74   16528.68   19551.9
# Cost of Production (`/Quintal) C2            1941.55    2172.46    1898.3
#
#                                                    3            4   \
# Crop                                            ARHAR        ARHAR
# State                                  Andhra Pradesh  Maharashtra
# Cost of Cultivation (`/Hectare) A2+FL        17051.66     17130.55
# Cost of Cultivation (`/Hectare) C2           24171.65     25270.26
# Cost of Production (`/Quintal) C2             3670.54       2775.8
#
#                                                 5         6               7   \
# Crop                                        COTTON    COTTON          COTTON
# State                                  Maharashtra    Punjab  Andhra Pradesh
# Cost of Cultivation (`/Hectare) A2+FL     23711.44   29047.1        29140.77
# Cost of Cultivation (`/Hectare) C2        33116.82  50828.83        44756.72
# Cost of Production (`/Quintal) C2          2539.47   2003.76         2509.99
#
#                                              8         9   ...  \
# Crop                                     COTTON    COTTON  ...
# State                                   Gujarat   Haryana  ...
# Cost of Cultivation (`/Hectare) A2+FL  29616.09  29918.97  ...
# Cost of Cultivation (`/Hectare) C2     42070.44  44018.18  ...
# Cost of Production (`/Quintal) C2       2179.26   2127.35  ...
#
#                                                          39             40  \
# Crop                                   RAPESEED AND MUSTARD      SUGARCANE
# State                                               Haryana  Uttar Pradesh
# Cost of Cultivation (`/Hectare) A2+FL              14715.27       24538.32
# Cost of Cultivation (`/Hectare) C2                 27507.54       45239.51
# Cost of Production (`/Quintal) C2                   1251.12          93.64
#
#                                               41              42           43  \
# Crop                                   SUGARCANE       SUGARCANE    SUGARCANE
# State                                  Karnataka  Andhra Pradesh  Maharashtra
# Cost of Cultivation (`/Hectare) A2+FL   55655.44        56621.16      57673.6
# Cost of Cultivation (`/Hectare) C2      86765.77        91442.63     85801.95
# Cost of Production (`/Quintal) C2          86.53          119.72       107.56
#
#                                                44              45        46  \
# Crop                                    SUGARCANE           WHEAT     WHEAT
# State                                  Tamil Nadu  Madhya Pradesh    Punjab
# Cost of Cultivation (`/Hectare) A2+FL    66335.06         12464.4  17945.58
# Cost of Cultivation (`/Hectare) C2       89025.27        22489.75  35423.48
# Cost of Production (`/Quintal) C2           85.79          810.25     804.8
#
#                                                   47         48
# Crop                                           WHEAT      WHEAT
# State                                  Uttar Pradesh  Rajasthan
# Cost of Cultivation (`/Hectare) A2+FL       18979.38   19119.08
# Cost of Cultivation (`/Hectare) C2          31902.74   29876.36
# Cost of Production (`/Quintal) C2             769.84     683.58
#
# [5 rows x 49 columns]

# %%
# checking number of data points for different crops
print(cultivation_data.Crop.value_counts())
# Out:
# Crop
# ARHAR                   5
# COTTON                  5
# GRAM                    5
# GROUNDNUT               5
# MAIZE                   5
# MOONG                   5
# PADDY                   5
# RAPESEED AND MUSTARD    5
# SUGARCANE               5
# WHEAT                   4
# Name: count, dtype: int64

# %%
# Checking columns of dataframe
print(cultivation_data.columns)

# Creating list of specific columns from dataframe
columns = ['Crop', 'State', 'Yield (Quintal/ Hectare) ']

# Creating subset of dataframe using list of specific columns
new_data = cultivation_data[columns]

# Pivoting the dataframe using keyword arguments
table = new_data.pivot(index='Crop', columns='State', values='Yield (Quintal/ Hectare) ')

# Filling NaN values with zero
table = table.fillna(0)

# Plotting (stacked bar plots) pivoted dataframe
table.plot(kind='bar', stacked=True, colormap='Paired')

# Setting Y label
plt.ylabel('Yield (Quintal/ Hectare)')

# Display the plot
plt.show()
# Out:
# Index(['Crop', 'State', 'Cost of Cultivation (`/Hectare) A2+FL',
#        'Cost of Cultivation (`/Hectare) C2',
#        'Cost of Production (`/Quintal) C2', 'Yield (Quintal/ Hectare) ',
#        'Per Hectare Cost Price', 'Cost of cultivation per hectare',
#        'Yield in Kg per hectare'],
#       dtype='object')

# %%
# plotting transposed dataframe
table.T.plot(kind='bar',stacked=True)
plt.ylabel('Yield (Quintal/ Hectare) ')
# setting legend location to best
plt.legend(loc='best')

# %%
columns = ['Crop', 'State', 'Yield in Kg per hectare']
new_data = cultivation_data[columns]

# Use keyword arguments for pivot
table = new_data.pivot(index='Crop', columns='State', values='Yield in Kg per hectare')

table = table.fillna(0)
ax = table.T.plot(kind='bar', stacked=True)

labels = []
for j in table.T.columns:
    for i in table.T.index:
        # values are added as factor to fit into plot
        label = round((int(table.T.loc[i][j])), 1)
        labels.append(label)

patches = ax.patches

for label, rect in zip(labels, patches):
    width = rect.get_width()
    if width > 0:
        x = rect.get_x()
        y = rect.get_y()
        height = rect.get_height()
        ax.text(x + width / 2., y + height / 2., label, ha='center', va='center')

plt.ylabel('Yield (Kg/ Hectare)')
# setting legend location to best
plt.legend(loc='best')

# %%
columns = ['Crop', 'State', 'Cost of cultivation per hectare']
new_data = cultivation_data[columns]
table = new_data.pivot(index='Crop', columns='State', values='Cost of cultivation per hectare')
table = table.fillna(0)
ax = table.T.plot(kind='bar', stacked=True)

labels = []
for j in table.T.columns:
    for i in table.T.index:
        label = round((int(table.T.loc[i][j]) / 10000), 1)
        labels.append(label)

patches = ax.patches

for label, rect in zip(labels, patches):
    width = rect.get_width()
    x = rect.get_x()
    y = rect.get_y()
    height = rect.get_height()
    ax.text(x + width / 2., y + height / 2., label, ha='center', va='center')

plt.ylabel('Cost of cultivation per hectare')
plt.show()

# %%
# now move to another dataset
crop_data = pd.read_csv("./input/datafile (2).csv")
print(crop_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Crop                55 non-null     object
#  1   Production 2006-07  55 non-null     float64
#  2   Production 2007-08  55 non-null     float64
#  3   Production 2008-09  55 non-null     float64
#  4   Production 2009-10  55 non-null     float64
#  5   Production 2010-11  55 non-null     float64
#  6   Area 2006-07        55 non-null     float64
#  7   Area 2007-08        55 non-null     float64
#  8   Area 2008-09        55 non-null     float64
#  9   Area 2009-10        55 non-null     float64
#  10  Area 2010-11        55 non-null     float64
#  11  Yield 2006-07       55 non-null     float64
#  12  Yield 2007-08       55 non-null     float64
#  13  Yield 2008-09       55 non-null     float64
#  14  Yield 2009-10       55 non-null     float64
#  15  Yield 2010-11       55 non-null     float64
# dtypes: float64(15), object(1)
# memory usage: 7.0+ KB
# None

# %%
print(crop_data.columns)
# Out:
# Index(['Crop             ', 'Production 2006-07', 'Production 2007-08',
#        'Production 2008-09', 'Production 2009-10', 'Production 2010-11',
#        'Area 2006-07', 'Area 2007-08', 'Area 2008-09', 'Area 2009-10',
#        'Area 2010-11', 'Yield 2006-07', 'Yield 2007-08', 'Yield 2008-09',
#        'Yield 2009-10', 'Yield 2010-11'],
#       dtype='object')

# %%
crop_data.columns = crop_data.columns.str.strip()

# %%
# Now the columns should be correctly named
columns = ['Crop', 'Production 2006-07', 'Production 2007-08', 'Production 2008-09', 'Production 2009-10', 'Production 2010-11']
columns2 = ['Crop', 'Area 2006-07', 'Area 2007-08', 'Area 2008-09', 'Area 2009-10', 'Area 2010-11']
columns3 = ['Crop', 'Yield 2006-07', 'Yield 2007-08', 'Yield 2008-09', 'Yield 2009-10', 'Yield 2010-11']

production = crop_data[columns].copy()
area = crop_data[columns2].copy()
yd = crop_data[columns3].copy()

production.index = production['Crop']
area.index = area['Crop']
yd.index = yd['Crop']

del production['Crop']
del area['Crop']
del yd['Crop']

print(production.head())
# Out:
#                   Production 2006-07  Production 2007-08  Production 2008-09  \
# Crop
# Total Foodgrains               158.8               168.6               171.3
# Rice                           200.8               207.9               213.3
# Wheat                          131.6               136.4               140.1
# Jowar                          124.3               137.8               126.0
# Bajra                          136.4               161.5               143.9
#
#                   Production 2009-10  Production 2010-11
# Crop
# Total Foodgrains               159.4               178.9
# Rice                           191.6               206.4
# Wheat                          140.3               150.8
# Jowar                          116.5               121.8
# Bajra                          105.4               167.9

# %%
# printing columns for transposed production dataframe
print(production.T.columns)
# Out:
# Index(['Total Foodgrains', 'Rice', 'Wheat', 'Jowar', 'Bajra', 'Maize', 'Ragi',
#        'Small millets', 'Barley', 'Coarse Cereals', 'Cereals', 'Gram', 'Arhar',
#        'Other Pulses', 'Total Pulses', 'Total Non-Food grains ',
#        'Total Oilseeds', 'Groundnut', 'Sesamum', 'Rapeseed &Mustard',
#        'Linseed', 'Castor seed', 'Safflower', 'Niger seed', 'Sunflower',
#        'Soyabean', 'Nine Oilseeds', 'Coconut', 'Cotton seed', 'Total Fibers',
#        'Cotton(lint)', 'Jute', 'Mesta', 'Jute & Mesta', 'Sannhamp ', 'Tea ',
#        'Coffee ', 'Rubber ', 'Total Spices', 'Black pepper', 'Dry chilies ',
#        'Dry ginger ', 'Turmeric ', 'Arecanut  ', 'Cardamom ', 'Coriander',
#        'Garlic  ', 'Total Fruits & Vegetables', 'Potato', 'Tapioca',
#        'Sweet potato  ', 'Onion', 'Banana  ', 'Sugarcane', 'Tobacco'],
#       dtype='object', name='Crop')

# %%
# Get current size of figure
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: current size
print("Current size:", fig_size)
# Set figure width to 12 and height to 9
fig_size[0] = 18
fig_size[1] = 18
plt.rcParams["figure.figsize"] = fig_size
# initialize i for loop
i=0
ax = production.T.plot(subplots=True,layout=(11,5),color='red',label='Production',legend=False)
# for loop on axes for setting titles for subplots
for a in ax.flat:
    a.set_title(production.index[i])
    i += 1
# plotting another dataframes on same plot
ax1 = area.T.plot(subplots=True,layout=(11,5),ax=ax, linestyle=':',marker='.',color='blue',legend=False)
ax2 = yd.T.plot(subplots=True,layout=(11,5),ax=ax, linestyle='--',marker="*",color='green',legend=False)
labels = ['Production','Area','Yield']
# setting X-axis labels
plt.xticks(np.arange(5),('2006-07','2007-08','2008-09','2009-10','2010-11'))
# placing the legend on the bottom of plot
plt.legend(labels=labels,loc='upper center', bbox_to_anchor=(-0.5, -0.5),  shadow=True, ncol=3, fontsize = 'xx-large')

plt.tight_layout()
# Out:
# Current size: [12.0, 9.0]
